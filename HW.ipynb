# %%
import numpy as np
import pandas as pd

# %%
#Q1
list = []
for i in range(0,1000):
    number = (str(i).zfill(4))
    list.append(number)

new_list = np.array(list)
new_list.reshape(20,50)
# Out:
# array([['0000', '0001', '0002', '0003', '0004', '0005', '0006', '0007',
#         '0008', '0009', '0010', '0011', '0012', '0013', '0014', '0015',
#         '0016', '0017', '0018', '0019', '0020', '0021', '0022', '0023',
#         '0024', '0025', '0026', '0027', '0028', '0029', '0030', '0031',
#         '0032', '0033', '0034', '0035', '0036', '0037', '0038', '0039',
#         '0040', '0041', '0042', '0043', '0044', '0045', '0046', '0047',
#         '0048', '0049'],
#        ['0050', '0051', '0052', '0053', '0054', '0055', '0056', '0057',
#         '0058', '0059', '0060', '0061', '0062', '0063', '0064', '0065',
#         '0066', '0067', '0068', '0069', '0070', '0071', '0072', '0073',
#         '0074', '0075', '0076', '0077', '0078', '0079', '0080', '0081',
#         '0082', '0083', '0084', '0085', '0086', '0087', '0088', '0089',
#         '0090', '0091', '0092', '0093', '0094', '0095', '0096', '0097',
#         '0098', '0099'],
# ...

# %%
#Q2
df = pd.read_excel("testA.xlsx", encoding = "utf-8")
df
# Out:
#           Date    Close  Adj Close
# 0   2019-11-24  3118.25    3118.25
# 1   2019-11-25  3132.75    3132.75
# 2   2019-11-26  3143.75    3143.75
# 3   2019-11-27  3153.75    3153.75
# 4   2019-11-29      NaN        NaN
# ..         ...      ...        ...
# 119 2020-04-17  2869.00    2869.00
# 120 2020-04-19  2847.50    2847.50
# 121 2020-04-20  2814.00    2814.00
# 122 2020-04-21  2736.50    2736.50
# 123 2020-04-22  2775.00    2775.00
#
# [124 rows x 3 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#           Date    Close  Adj Close
# 0   2019-11-24  3118.25    3118.25
# 1   2019-11-25  3132.75    3132.75
# 2   2019-11-26  3143.75    3143.75
# 3   2019-11-27  3153.75    3153.75
# 5   2019-12-01  3146.75    3146.75
# ..         ...      ...        ...
# 119 2020-04-17  2869.00    2869.00
# 120 2020-04-19  2847.50    2847.50
# 121 2020-04-20  2814.00    2814.00
# 122 2020-04-21  2736.50    2736.50
# 123 2020-04-22  2775.00    2775.00
#
# [121 rows x 3 columns]
